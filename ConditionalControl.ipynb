# %%
x = 10
if x > 5:
  print("x is greter than 5")
# Out:
# x is greter than 5

# %%
x = 3
if x % 2 == 0:
  print("x is even")
else:
  print("x is odd")
# Out:
# x is odd

# %%
name = input("Enter the name")

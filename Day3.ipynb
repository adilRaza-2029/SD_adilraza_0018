# %%
l = [1,3,9]
l1 = []
for i in l:
  l1.append(i**2)
print(l1)
# Out:
# [1, 9, 81]

# %%
l = [1,2,3,4,45,5]
[i**2 for i in l]
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
[i for i in l if i % 2 == 0]
# Out:
# [2, 4]

# %%
l1 = ["sudha", "skills" , "kumar" , "data science"]

# %%
[i.upper() for i in l1]
# Out:
# ['SUDHA', 'SKILLS', 'KUMAR', 'DATA SCIENCE']

# %%
l
# Out:
# [1, 2, 3, 4, 45, 5]

# %%
list(i**2 for i in l)
# Out:
# [1, 4, 9, 16, 2025, 25]

# %%
d = {"key1" : 1 , "key2" : 2, "key3" : 3, "key4" : 4}

# %%
d1 = {}
for i in d:
  d1[i] = d[i]**2
print(d1)
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3), ('key4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}

# %%
{k : v for k , v in d.items() if v > 1}
# Out:
# {'key2': 2, 'key3': 3, 'key4': 4}

# %%
def test1():
  print("this is my very very first function")

# %%
test1()
# Out:
# this is my very very first function

# %%
def sum(a,b):
  sum = 0
  sum = a + b
  return sum
a = int(input("Enter a num:"))
b = int(input("Enter a num:"))
print(sum(a,b))
# Out:
# Enter a num:4
# Enter a num:5
# 9

# %%
test1() + "adil"
# Out:
# this is my very very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_463/684062260.py in <cell line: 0>()
# ----> 1 test1() + "adil"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
  return "this is my very very first function"

# %%
test2()
# Out:
# 'this is my very very first function'

# %%
test2() + " adil"
# Out:
# 'this is my very very first function adil'

# %%
def test3():
  return "sudh",23,345.56,[1,2,3,3]

# %%
test3()
# Out:
# ('sudh', 23, 345.56, [1, 2, 3, 3])

# %%
a,b,c,d = test3()

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# sudh
# 23
# 345.56
# [1, 2, 3, 3]

# %%
def add():
  a = 5+6/7
  return a

# %%
add()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
  d = a+b/c
  return d

# %%
test5(4,5,6.78)
# Out:
# 4.737463126843657

# %%
test5(2,5,8)
# Out:
# 2.625

# %%
def test6(a,b):
  return a+b

# %%
test6(3,4)
# Out:
# 7

# %%
test6("adil"," raza")
# Out:
# 'adil raza'

# %%
test6(("adil","raza"),("sudh","kumar"))
# Out:
# ('adil', 'raza', 'sudh', 'kumar')

# %%
test6(["adil","raza"],["sudh","kumar"])
# Out:
# ['adil', 'raza', 'sudh', 'kumar']

# %%
test6({"Adil": "Raza"},{"sudh" : "kumar"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_463/3345077972.py in <cell line: 0>()
# ----> 1 test6({"Adil": "Raza"},{"sudh" : "kumar"})
#
# /tmp/ipykernel_463/2790025198.py in test6(a, b)
#       1 def test6(a,b):
# ----> 2   return a+b
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
def test11(*args):
  return args

# %%
type(test11())
# Out:
# tuple

# %%
def test12(*args):
  return args + (1,2,3,4)

# %%
test12()
# Out:
# (1, 2, 3, 4)

# %%
def test12(*args):
  return args + [1,2,3,4]

# %%
test12()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_463/1723208909.py in <cell line: 0>()
# ----> 1 test12()
#
# /tmp/ipykernel_463/2891445006.py in test12(*args)
#       1 def test12(*args):
# ----> 2   return args + [1,2,3,4]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
def test13(*kwargs):
  return kwargs + [1,2,3,4]

# %%
test13()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_463/2550155749.py in <cell line: 0>()
# ----> 1 test13()
#
# /tmp/ipykernel_463/3113338333.py in test13(*kwargs)
#       1 def test13(*kwargs):
# ----> 2   return kwargs + [1,2,3,4]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %%
def test13(*kwargs):
  return kwargs + (1,2,3,4)

# %%
test13()
# Out:
# (1, 2, 3, 4)

# %%
test11(1,2,3,"sudh","kumar",[1,2,3,4,4])
# Out:
# (1, 2, 3, 'sudh', 'kumar', [1, 2, 3, 4, 4])

# %%
def test12(*sudh):
  return sudh

# %%
test12(1,2,34,4)
# Out:
# (1, 2, 34, 4)

# %%
def test13(*args,a):
  return args , a

# %%
test13(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_463/2288133206.py in <cell line: 0>()
# ----> 1 test13(1,2,3,4)
#
# TypeError: test13() missing 1 required keyword-only argument: 'a'

# %%
test13(1,2,3,4,a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def test14(c,d,a=23,b=1):
  return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_463/3076521518.py in <cell line: 0>()
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(2,5,a=2342)
# Out:
# (2342, 1, 2, 5)

# %%
def test15(**kwargs):
  return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4],b="sudh",c=23.45)
# Out:
# {'a': [1, 2, 3, 4], 'b': 'sudh', 'c': 23.45}

# %%
def add(a,b):
  return a+b
def sub(a,b):
  return a-b
def mul(a,b):
  return a*b
def div(a,b):
  return a/b

# %%
operation = input("enter operation: ")
num1 = int(input("enter num: "))
num2 = int(input("enter another num: "))
if operation == "+":
  print("Addition is ",add(num1,num2))
elif operation == "-":
  print("Subtraction is ",sub(num1,num2))
elif operation == "*":
  print("Multiplication is ",mul(num1,num2))
elif operation == "/":
  print("Division is ",div(num1,num2))
else:
  print("invalid operation")
# Out:
# enter operation: +
# enter num: 3
# enter another num: 4
# Addition is  7

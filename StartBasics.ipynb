# %%
1+1
x=1

# %%
5*5
# Out:
# 25

# %%
x = 10

# %%
x
# Out:
# 10

# %%
type(x)
# Out:
# int

# %%
a = 5

# %%
b=11

# %%
a + b
# Out:
# 16

# %%
a * b
# Out:
# 55

# %%
a - b
# Out:
# -6

# %%
div = a / b

# %%
a // b
# Out:
# 0

# %%
a % b
# Out:
# 5

# %%
c = "adil"

# %%
type(c)
# Out:
# str

# %%
type(div)
# Out:
# float

# %%
f = False/True

# %%
True+True
# Out:
# 2

# %%
True * True
# Out:
# 1

# %%
f
# Out:
# 0.0
